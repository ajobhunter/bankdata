# %% [markdown]
# # Project Shoefly order

# %%
import pandas as pd

# %% [markdown]
# > 1. Load the data from `PP-L2-shoefly.csv` (into the variable `orders_df` (Url: https://drive.google.com/u/1/uc?id=1TxuhuoNCG8y4nvnAPxtq7-N7NI7X4dG1&export=download)
# 2. Inspect the first 5 lines of the data.
# 3. Select all of the email addresses from the column email and save them to a variable called `emails`.
# 4. Frances Palmer claims that her order was wrong. What did Frances Palmer order?
# 5. Select all orders where `shoe_type` is in clogs, boots, and ballet flats (Hint: `df.isin()`)

# %% [markdown]
# 1. Load the data from PP-L2-shoefly.csv (into the variable orders_df (Url: https://drive.google.com/u/1/uc?id=1TxuhuoNCG8y4nvnAPxtq7-N7NI7X4dG1&export=download)

# %%
# Type your code below
order_df=pd.read_csv("https://drive.google.com/u/1/uc?id=1TxuhuoNCG8y4nvnAPxtq7-N7NI7X4dG1&export=download")

# %%
df.to_csv('')

# %% [markdown]
# 2. Inspect the first 5 lines of the data.

# %%
order_df.head(10)
# Out:
#       id first_name last_name  gender                         email  \
# 0  54791    Rebecca   Lindsay  female  RebeccaLindsay57@hotmail.com
# 1  53450      Emily     Joyce  female        EmilyJoyce25@gmail.com
# 2  91987      Joyce    Waller  female        Joyce.Waller@gmail.com
# 3  14437     Justin  Erickson    male   Justin.Erickson@outlook.com
# 4  79357     Andrew     Banks    male              AB4318@gmail.com
# 5  52386      Julie     Marsh  female        JulieMarsh59@gmail.com
# 6  20487     Thomas    Jensen    male              TJ5470@gmail.com
# 7  76971     Janice     Hicks  female        Janice.Hicks@gmail.com
# 8  21586    Gabriel    Porter    male     GabrielPorter24@gmail.com
# 9  62083    Frances    Palmer  female     FrancesPalmer50@gmail.com
#
#       shoe_type shoe_material shoe_color
# 0         clogs  faux-leather      black
# 1  ballet flats  faux-leather       navy
# 2       sandles        fabric      black
# 3         clogs  faux-leather        red
# ...

# %% [markdown]
# 3. Select all of the email addresses from the column email and save them to a variable called emails.

# %%
email_address = order_df['email']
email_address
# Out:
# 0     RebeccaLindsay57@hotmail.com
# 1           EmilyJoyce25@gmail.com
# 2           Joyce.Waller@gmail.com
# 3      Justin.Erickson@outlook.com
# 4                 AB4318@gmail.com
# 5           JulieMarsh59@gmail.com
# 6                 TJ5470@gmail.com
# 7           Janice.Hicks@gmail.com
# 8        GabrielPorter24@gmail.com
# 9        FrancesPalmer50@gmail.com
# 10         JessicaHale25@gmail.com
# 11      LawrenceParker44@gmail.com
# 12         SusanDennis58@gmail.com
# 13                DO2680@gmail.com
# 14       Rebecca.Charles@gmail.com
# 15              JC2072@hotmail.com
# 16              VS4753@outlook.com
# 17          RoyTillman20@gmail.com
# 18       Thomas.Roberson@gmail.com
# 19         ANewton1977@outlook.com
# Name: email, dtype: object

# %% [markdown]
# 4. Frances Palmer claims that her order was wrong. What did Frances Palmer order?

# %%
order_df[(order_df["first_name"]=="Frances") & (order_df["last_name"]=="Palmer")]
# Out:
#       id first_name last_name  gender                      email shoe_type  \
# 9  62083    Frances    Palmer  female  FrancesPalmer50@gmail.com    wedges
#
#   shoe_material shoe_color
# 9       leather      white

# %% [markdown]
# 5. Select all orders where shoe_type is in clogs, boots, and ballet flats (Hint: df.isin())

# %%
order_df[order_df['shoe_type'].isin(['clogs','boots','ballet flats'])]
# Out:
#        id first_name   last_name  gender                         email  \
# 0   54791    Rebecca     Lindsay  female  RebeccaLindsay57@hotmail.com
# 1   53450      Emily       Joyce  female        EmilyJoyce25@gmail.com
# 3   14437     Justin    Erickson    male   Justin.Erickson@outlook.com
# 4   79357     Andrew       Banks    male              AB4318@gmail.com
# 6   20487     Thomas      Jensen    male              TJ5470@gmail.com
# 7   76971     Janice       Hicks  female        Janice.Hicks@gmail.com
# 8   21586    Gabriel      Porter    male     GabrielPorter24@gmail.com
# 10  91629    Jessica        Hale  female       JessicaHale25@gmail.com
# 12  45832      Susan      Dennis  female       SusanDennis58@gmail.com
# 14  73431    Rebecca     Charles  female     Rebecca.Charles@gmail.com
# 16  39888    Vincent  Stephenson    male            VS4753@outlook.com
# 17  35961        Roy     Tillman    male        RoyTillman20@gmail.com
#
#        shoe_type shoe_material shoe_color
# ...

# %%
#import->create new dataframe->save dataframe to csv->use variable and read csv

#import
import pandas as pd

#create new dataframe
create_df = pd.DataFrame ([
    ['John Smith', '123 Main St.', 34],
    ['Jane Doe', '456 Maple Ave.', 28],
    ['Joe Schmo', '789 Broadway', 51],
    ],
    columns=['name', 'address', 'age']
    )

# %%
#save dataframe to csv
create_df.to_csv("create.csv",index=False)
#tablename_df.to_csv("csvname.csv",index=False)
#index=False:no extra column
#index=True:extra column

#use variable and read csv
variable_df=pd.read_csv("create.csv")
variable_df

# %%
#already have online data from csv, just read csv
#import->use variable and read csv
import pandas as pd
onlinedata_df=pd.read_csv("googlelink")
onlinedata_df
