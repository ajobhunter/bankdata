# %% [markdown]
# # Project DANGER Menu

# %% [markdown]
# 1. We have four different menus: brunch, early-bird, dinner, and kids. Create a `Menu` class .

# %%
# Type your code below
class Menu:
    pass

# %% [markdown]
# 2. Give `Menu` a constructor with the five parameters `self`, `name`, `items`, `start_time`, and `end_time`.

# %%
# Type your code below
class Menu:
    def __init__(self, name, items, start_time, end_time):
        self.name = name
        self.items = items
        self.start_time = start_time
        self.end_time = end_time

# %% [markdown]
# 3. Let’s create our first menu: brunch. Brunch is served from 11am to 4pm. The following `items` are sold during brunch:
#
# ```python
# {
#     'pancakes': 7.50,
#     'waffles': 9.00,
#     'burger': 11.00,
#     'home fries': 4.50,
#     'coffee': 1.50,
#     'espresso': 3.00,
#     'tea': 1.00,
#     'mimosa': 10.50,
#     'orange juice': 3.50
# }
# ```

# %%
# Type your code below
brunch_menu_dict = {
    'pancakes': 7.50,
    'waffles': 9.00,
    'burger': 11.00,
    'home fries': 4.50,
    'coffee': 1.50,
    'espresso': 3.00,
    'tea': 1.00,
    'mimosa': 10.50,
    'orange juice': 3.50
}
brunch_menu = Menu("brunch", brunch_menu_dict, "11am", "4pm")

# %% [markdown]
# 4. Let’s create our second menu item early_bird. Early-bird Dinners are served from 3pm to 6pm. The following items are available during the early-bird menu:
#
# ```python
# {
#     'salumeria plate': 8.00,
#     'salad and breadsticks (serves 2, no refills)': 14.00,
#     'pizza with quattro formaggi': 9.00,
#     'duck ragu': 17.50,
#     'mushroom ravioli (vegan)': 13.50,
#     'coffee': 1.50,
#     'espresso': 3.00
# }
# ```

# %%
# Type your code below
early_bird_menu_dict={
    'salumeria plate': 8.00,
    'salad and breadsticks (serves 2, no refills)': 14.00,
    'pizza with quattro formaggi': 9.00,
    'duck ragu': 17.50,
    'mushroom ravioli (vegan)': 13.50,
    'coffee': 1.50,
    'espresso': 3.00
}
early_bird_menu = Menu("early_bird", early_bird_menu_dict, "3pm", "6pm")

# %% [markdown]
# 5. Let’s create our third menu, dinner. Dinner is served from 5pm to 11pm. The following items are available for dinner:
#
# ```python
# {
#     'crostini with eggplant caponata': 13.00,
#     'ceaser salad': 16.00,
#     'pizza with quattro formaggi': 11.00,
#     'duck ragu': 19.50,
#     'mushroom ravioli': 13.50,
#     'coffee': 2.00,
#     'espresso': 3.00
# }
# ```

# %%
# Type your code below
dinner_menu_dict = {
    'crostini with eggplant caponata': 13.00,
    'ceaser salad': 16.00,
    'pizza with quattro formaggi': 11.00,
    'duck ragu': 19.50,
    'mushroom ravioli (vegan)': 13.50,
    'coffee': 2.00,
    'espresso': 3.00
}
dinner_menu = Menu("dinner",dinner_menu_dict,"5pm","11pm")

# %% [markdown]
# 6. And let’s create our last menu, kids. The kids menu is available from 11am until 9pm. The following items are available on the kids menu
#
# ```python
# {
#     'chicken nuggets': 6.50,
#     'fusilli with wild mushrooms': 12.00,
#     'apple juice': 3.00
# }
# ```

# %%
# Type your code below
kids_menu_dict = {
    'chicken nuggets': 6.50,
    'fusilli with wild mushrooms': 12.00,
    'apple juice': 3.00
}

kids_menu = Menu("kids",kids_menu_dict,"11am","9pm")

# %% [markdown]
# 7. Give our Menu class a string representation method(```__repr__```) that will tell you the name of the menu. Also, indicate in this representation when the menu is available.

# %%
print(brunch_menu)
# Out:
# <__main__.Menu object at 0x7ea3a20057b0>

# %%
# Type your code below
class Menu:
    def __init__(self, name, items, start_time, end_time):
        self.name = name
        self.items = items
        self.start_time = start_time
        self.end_time = end_time
    def __repr__(self):
        return f"""Menu Name: {self.name}
Available from {self.start_time} to {self.end_time}"""

# %% [markdown]
# 8. Try out our string representation. If you call `print(brunch_menu)` it should print out something like the following:
#
# ```
# brunch menu available from 11am to 4 pm
# ```

# %%
# Type your code below
brunch_menu = Menu(
    "brunch",
    {'pancakes': 7.50,
    'waffles': 9.00,
    'burger': 11.00,
    'home fries': 4.50,
    'coffee': 1.50,
    'espresso': 3.00,
    'tea': 1.00,
    'mimosa': 10.50,
    'orange juice': 3.50},
    "11am",
    "4pm")
print(brunch_menu)
# Out:
# Menu Name: brunch
# Available from 11am to 4pm

# %% [markdown]
# 9. Give Menu a method .calculate_bill() that has two parameters: `self`, and `purchased_items`, a list of the names of purchased items.
#
# Have `calculate_bill` return the total price of a purchase consisiting of all the items in `purchased_items`.

# %%
# Type your code below
class Menu:
    def __init__(self, name, items, start_time, end_time):
        self.name = name
        self.items = items
        self.start_time = start_time
        self.end_time = end_time

    def __repr__(self):
        return f"""Menu Name: {self.name}
Available from {self.start_time} to {self.end_time}
Menu Content:{self.items}"""

    def calculate_bill(self, purchased_items):
        total_bill = 0
        for item in purchased_items:
            if item in self.items:
                total_bill += self.items[item]
        return total_bill

# %% [markdown]
# 10. Test out `Menu.calculate_bill()`. We have a breakfast order for one order of `pancakes`, one order of `home fries`, and one `coffee`. Pass that into `brunch_menu.calculate_bill()` and print out the price. You should get 13.5

# %%
# Type your code below
breakfast_menu = Menu(
    "breakfast",
    {'pancakes': 7.50,
    'waffles': 9.00,
    'burger': 11.00,
    'home fries': 4.50,
    'coffee': 1.50,
    'espresso': 3.00,
    'tea': 1.00,
    'mimosa': 10.50,
    'orange juice': 3.50},
    "11am",
    "4pm")

breakfast_menu.calculate_bill(["pancakes", "home fries", "coffee"])
# Out:
# 13.5

# %% [markdown]
# 11. What about an early-bird purchase? Our last guests ordered the `salumeria plate` and the `mushroom ravioli`. Calculate the bill with .caluclate_bill(). You should get 21.5

# %%
# Type your code below
early_bird_menu = Menu(
    "early-bird-menu",
    {
    'salumeria plate': 8.00,
    'salad and breadsticks (serves 2, no refills)': 14.00,
    'pizza with quattro formaggi': 9.00,
    'duck ragu': 17.50,
    'mushroom ravioli (vegan)': 13.50,
    'coffee': 1.50,
    'espresso': 3.00
    },
    "3pm",
    "6pm"
)

early_bird_menu.calculate_bill(["salumeria plate", "mushroom ravioli (vegan)"])
# Out:
# 21.5
