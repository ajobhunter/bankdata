# %% [markdown]
# Basic Exploratory Data Analysis (EDA) of Bank loan

# %%
#Dataset:
#https://www.kaggle.com/datasets/zaurbegiev/my-dataset

#EDA
#https://www.kaggle.com/code/abdallhwerby/eda-preprocessing-and-classification

# %% [markdown]
# import library

# %%
#import library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load csv file data

# %%
data = pd.read_csv (r'bank_loan.csv')

# %% [markdown]
# View data

# %%
data.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid               445412  Short Term         709.0      1167493.0
# 1  Fully Paid               262328  Short Term           NaN            NaN
# 2  Fully Paid             99999999  Short Term         741.0      2231892.0
# 3  Fully Paid               347666   Long Term         721.0       806949.0
# 4  Fully Paid               176220  Short Term           NaN            NaN
#
#   Years in current job Home Ownership             Purpose  Monthly Debt  \
# 0              8 years  Home Mortgage   Home Improvements       5214.74
# 1            10+ years  Home Mortgage  Debt Consolidation      33295.98
# 2              8 years       Own Home  Debt Consolidation      29200.53
# 3              3 years       Own Home  Debt Consolidation       8741.90
# 4              5 years           Rent  Debt Consolidation      20639.70
#
#    Years of Credit History  Months since last delinquent  \
# 0                     17.2                           NaN
# 1                     21.1                           8.0
# 2                     14.9                          29.0
# 3                     12.0                           NaN
# 4                      6.1                           NaN
#
#    Number of Open Accounts  Number of Credit Problems  Current Credit Balance  \
# 0                      6.0                        1.0                228190.0
# 1                     35.0                        0.0                229976.0
# 2                     18.0                        1.0                297996.0
# 3                      9.0                        0.0                256329.0
# 4                     15.0                        0.0                253460.0
#
#    Maximum Open Credit  Bankruptcies  Tax Liens
# 0             416746.0           1.0        0.0
# 1             850784.0           0.0        0.0
# 2             750090.0           0.0        0.0
# 3             386958.0           0.0        0.0
# 4             427174.0           0.0        0.0

# %%
data.shape
# Out:
# (22305, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22305 entries, 0 to 22304
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Loan ID                       22305 non-null  object
#  1   Customer ID                   22305 non-null  object
#  2   Loan Status                   22305 non-null  object
#  3   Current Loan Amount           22305 non-null  int64
#  4   Term                          22305 non-null  object
#  5   Credit Score                  17975 non-null  float64
#  6   Annual Income                 17975 non-null  float64
#  7   Years in current job          21364 non-null  object
#  8   Home Ownership                22305 non-null  object
#  9   Purpose                       22305 non-null  object
#  10  Monthly Debt                  22305 non-null  float64
#  11  Years of Credit History       22305 non-null  float64
#  12  Months since last delinquent  10322 non-null  float64
#  13  Number of Open Accounts       22304 non-null  float64
#  14  Number of Credit Problems     22304 non-null  float64
#  15  Current Credit Balance        22304 non-null  float64
#  16  Maximum Open Credit           22304 non-null  float64
#  17  Bankruptcies                  22257 non-null  float64
#  18  Tax Liens                     22300 non-null  float64
# dtypes: float64(11), int64(1), object(7)
# memory usage: 3.2+ MB

# %%
data.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Current Loan Amount  Credit Score  Annual Income   Monthly Debt  \
# count         2.230500e+04  17975.000000   1.797500e+04   22305.000000
# mean          1.169189e+07   1083.806620   1.377734e+06   18460.911624
# std           3.170032e+07   1488.735985   9.327020e+05   12194.955902
# min           1.124200e+04    585.000000   9.703300e+04       0.000000
# 25%           1.797180e+05    705.000000   8.483310e+05   10187.040000
# 50%           3.136980e+05    724.000000   1.168272e+06   16201.110000
# 75%           5.258880e+05    741.000000   1.640850e+06   23964.890000
# max           1.000000e+08   7510.000000   3.083900e+07  205801.350000
#
#        Years of Credit History  Months since last delinquent  \
# count             22305.000000                  10322.000000
# mean                 18.168742                     35.167313
# std                   6.933257                     22.041817
# min                   2.000000                      0.000000
# 25%                  13.500000                     16.000000
# 50%                  16.900000                     32.000000
# 75%                  21.600000                     51.000000
# max                  65.000000                    152.000000
#
#        Number of Open Accounts  Number of Credit Problems  \
# count             22304.000000               22304.000000
# mean                 11.151004                   0.169476
# std                   5.019915                   0.478726
# min                   0.000000                   0.000000
# 25%                   8.000000                   0.000000
# 50%                  10.000000                   0.000000
# 75%                  14.000000                   0.000000
# max                  56.000000                  11.000000
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies     Tax Liens
# count            2.230400e+04         2.230400e+04  22257.000000  22300.000000
# mean             2.963421e+05         7.663868e+05      0.119783      0.027848
# std              4.147430e+05         6.348011e+06      0.352067      0.242351
# min              0.000000e+00         0.000000e+00      0.000000      0.000000
# 25%              1.120382e+05         2.733720e+05      0.000000      0.000000
# 50%              2.097125e+05         4.663010e+05      0.000000      0.000000
# 75%              3.696308e+05         7.870115e+05      0.000000      0.000000
# max              3.287897e+07         6.324777e+08      5.000000     11.000000

# %%
data.hist(bins=25,figsize=(20,10));

# %% [markdown]
# Check missing value

# %%
data.isnull().any()
# Out:
# Loan ID                         False
# Customer ID                     False
# Loan Status                     False
# Current Loan Amount             False
# Term                            False
# Credit Score                     True
# Annual Income                    True
# Years in current job             True
# Home Ownership                  False
# Purpose                         False
# Monthly Debt                    False
# Years of Credit History         False
# Months since last delinquent     True
# Number of Open Accounts          True
# Number of Credit Problems        True
# Current Credit Balance           True
# Maximum Open Credit              True
# Bankruptcies                     True
# Tax Liens                        True
# dtype: bool

# %%
data.isnull().sum()
# Out:
# Loan ID                             0
# Customer ID                         0
# Loan Status                         0
# Current Loan Amount                 0
# Term                                0
# Credit Score                     4330
# Annual Income                    4330
# Years in current job              941
# Home Ownership                      0
# Purpose                             0
# Monthly Debt                        0
# Years of Credit History             0
# Months since last delinquent    11983
# Number of Open Accounts             1
# Number of Credit Problems           1
# Current Credit Balance              1
# Maximum Open Credit                 1
# Bankruptcies                       48
# Tax Liens                           5
# dtype: int64

# %%
# Check the percentage of Nan in dataset
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum()/data['Loan Status'].count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                               Total   Percent
# Months since last delinquent  11983  0.537234
# Credit Score                   4330  0.194127
# Annual Income                  4330  0.194127
# Years in current job            941  0.042188
# Bankruptcies                     48  0.002152
# Tax Liens                         5  0.000224
# Maximum Open Credit               1  0.000045
# Current Credit Balance            1  0.000045
# Number of Credit Problems         1  0.000045
# Number of Open Accounts           1  0.000045
# Years of Credit History           0  0.000000
# Loan ID                           0  0.000000
# Monthly Debt                      0  0.000000
# Customer ID                       0  0.000000
# Home Ownership                    0  0.000000
# Term                              0  0.000000
# Current Loan Amount               0  0.000000
# Loan Status                       0  0.000000
# Purpose                           0  0.000000

# %% [markdown]
# 51% missing data in total Months since last deliquent.
# 19% in both credit score and annual income.

# %%
#Drop the columns with > 50% missing
data.drop(columns = 'Months since last delinquent', axis=1, inplace=True)

# %% [markdown]
# Drop last 514 rows as they are all NaN

# %%
data.drop(data.tail(514).index, inplace=True)

# %%
data.isnull().sum()
# Out:
# Loan ID                         0
# Customer ID                     0
# Loan Status                     0
# Current Loan Amount             0
# Term                            0
# Credit Score                 4225
# Annual Income                4225
# Years in current job          922
# Home Ownership                  0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             0
# Bankruptcies                   46
# Tax Liens                       4
# dtype: int64

# %% [markdown]
# filling missing data:

# %% [markdown]
# Before completing the missing values, we check the distribution to decide the better representation of central tendency:

# %% [markdown]
# Credit Score

# %%
sns.histplot(x= 'Credit Score',data =data)
# Out:
# <Axes: xlabel='Credit Score', ylabel='Count'>

# %% [markdown]
# use median: for imputation in the case of outliers.

# %%
median= data['Credit Score'].median()
data['Credit Score'].fillna(median, inplace=True)

# %% [markdown]
# Annual Income

# %%
value_counts = data['Annual Income'].value_counts()
print(value_counts)
data['Annual Income'].head()
# Out:
# Annual Income
# 1330532.0    8
# 1328803.0    8
# 1146612.0    7
# 1118644.0    6
# 763344.0     6
#             ..
# 1709829.0    1
# 3864600.0    1
# 458565.0     1
# 3752880.0    1
# 2001308.0    1
# Name: count, Length: 13654, dtype: int64
# 0    1167493.0
# 1          NaN
# 2    2231892.0
# 3     806949.0
# 4          NaN
# Name: Annual Income, dtype: float64

# %%
sns.histplot(x= 'Annual Income',data =data)
# Out:
# <Axes: xlabel='Annual Income', ylabel='Count'>

# %% [markdown]
# It's better to use median.

# %%
median= data['Annual Income'].median()
data['Annual Income'].fillna(median, inplace=True)

# %% [markdown]
# Years in current job

# %%
sns.histplot(x= 'Years in current job',data =data)
# Out:
# <Axes: xlabel='Years in current job', ylabel='Count'>

# %% [markdown]
# It's better to use mean.

# %%
le = LabelEncoder()
data['Years in current job']=le.fit_transform(data['Years in current job'])

# %%
imputer = SimpleImputer(strategy='mean', missing_values=np.nan)
imputer = imputer.fit(data[['Years in current job']])
data['Years in current job'] = imputer.transform(data[['Years in current job']])

# %%
mean= data['Years in current job'].mean()
data['Years in current job'].fillna(mean, inplace=True)

# %% [markdown]
# Maximum Open Credit

# %%
sns.histplot(x= 'Maximum Open Credit',data =data)
# Out:
# <Axes: xlabel='Maximum Open Credit', ylabel='Count'>

# %% [markdown]
# Use Median

# %%
median= data['Maximum Open Credit'].median()
data['Maximum Open Credit'].fillna(median, inplace=True)

# %%
mean= data['Bankruptcies'].mean()
data['Bankruptcies'].fillna(mean, inplace=True)

# %%
sns.histplot(x= 'Bankruptcies',data =data)
# Out:
# <Axes: xlabel='Bankruptcies', ylabel='Count'>

# %% [markdown]
# It's better to use median.

# %%
median=data['Bankruptcies'].median()
data['Bankruptcies'].fillna(mean, inplace=True)

# %% [markdown]
# Tax Liens

# %%
sns.histplot(x= 'Tax Liens',data =data)
# Out:
# <Axes: xlabel='Tax Liens', ylabel='Count'>

# %% [markdown]
# It's better to use mode.

# %%
mean=data['Tax Liens'].mean()
data['Tax Liens'].fillna(mean, inplace=True)

# %%
data.isnull().sum()
# Out:
# Loan ID                      0
# Customer ID                  0
# Loan Status                  0
# Current Loan Amount          0
# Term                         0
# Credit Score                 0
# Annual Income                0
# Years in current job         0
# Home Ownership               0
# Purpose                      0
# Monthly Debt                 0
# Years of Credit History      0
# Number of Open Accounts      0
# Number of Credit Problems    0
# Current Credit Balance       0
# Maximum Open Credit          0
# Bankruptcies                 0
# Tax Liens                    0
# dtype: int64

# %% [markdown]
# Data Visualization

# %%
plt.figure(figsize=(6,6))
plt.pie(x=data['Term'].value_counts(),labels=['short term','long term'])
plt.title('Time Period of Taking Loan')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='Home Ownership',data=data,hue='Loan Status')
plt.title('Own Property vs Loan Status',fontdict={'fontsize':20})
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='Purpose',data=data,hue='Loan Status')
plt.xticks(rotation=90)
plt.title('Purpose of taking Loan',fontdict={'fontsize':20})
plt.show()

# %% [markdown]
# Most loan borrowers take loan because of debt consolidation
