# %% [markdown]
# 1. What question(s) are you trying to solve (or prove wrong)?
#
# Answer: Is there any corelation between the happiness level, alcohol consumption level and their respective region?
#
# 2. What kind of data do you have and how do you treat different types?
#
# - Qualitative data: Country, Region, Hemisphere
# - Quantitative: There are no discrete data but Happiness score, HDI and all the alcohol consumption data are continuous data
# 3. What’s missing from the data and how do you deal with it?
# Answer: It will be helpful if i can know more about the country, like where do those countries are located in the world, or the climate and popoulation density of the countries then I can further draw more conclusion of the happiness level and the geographic location.
# 4. Where are the outliers and why should you care about them?
#
# 5. How can you add, change or remove features to get more out of your data?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pandas as pd
import numpy as np
sns.set(color_codes=True) 
mpl.rcParams['figure.figsize'] = [25, 18] 
plt.style.use('seaborn-pastel')

# %%
df = pd.read_csv('/Users/Anson/EDA project/HappinessAlcoholConsumption.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           122 non-null    object
#  1   Region            122 non-null    object
#  2   Hemisphere        122 non-null    object
#  3   HappinessScore    122 non-null    float64
#  4   HDI               122 non-null    int64
#  5   GDP_PerCapita     122 non-null    float64
#  6   Beer_PerCapita    122 non-null    int64
#  7   Spirit_PerCapita  122 non-null    int64
#  8   Wine_PerCapita    122 non-null    int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 8.7+ KB

# %%
df.isnull().any()
# Out:
# Country             False
# Region              False
# Hemisphere          False
# HappinessScore      False
# HDI                 False
# GDP_PerCapita       False
# Beer_PerCapita      False
# Spirit_PerCapita    False
# Wine_PerCapita      False
# dtype: bool

# %%
df.head(5)
# Out:
#        Country          Region Hemisphere  HappinessScore  HDI  GDP_PerCapita  \
# 0      Denmark  Western Europe      north           7.526  928         53.579
# 1  Switzerland  Western Europe      north           7.509  943         79.866
# 2      Iceland  Western Europe      north           7.501  933         60.530
# 3       Norway  Western Europe      north           7.498  951         70.890
# 4      Finland  Western Europe      north           7.413  918         43.433
#
#    Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita
# 0             224                81             278
# 1             185               100             280
# 2             233                61              78
# 3             169                71             129
# 4             263               133              97

# %% [markdown]
# Country
#
# Region =Region the country belongs to
#
# Hemisphere = Hemisphere of country
#
# HappinessScore =  A metric measured in 2016 by asking the sampled people the question: "How would you rate your happiness on a scale of 0 to 10 where 10 is the happiest"
#
# HDI = Human Development Index by United Nations Development Programme
#
# GDP_PerCapita = Gross Domestic Product index
#
# Beer_PerCapita = Liters ( per capita ) of beer consumption
#
# Spirit_PerCapita = Consumption of spirits drink ( per capita )
#
# Wine_PerCapita = Wine consumption

# %%
df.describe()
# Out:
#        HappinessScore         HDI  GDP_PerCapita  Beer_PerCapita  \
# count      122.000000  122.000000     122.000000      122.000000
# mean         5.524828  740.877049      91.482836      137.565574
# std          1.148736  149.846124     209.577313      104.817353
# min          3.069000  351.000000       1.029000        1.000000
# 25%          4.528250  663.750000       4.134250       38.250000
# 50%          5.542000  757.500000      12.016000      125.500000
# 75%          6.477000  861.500000      41.990000      224.750000
# max          7.526000  951.000000     953.000000      376.000000
#
#        Spirit_PerCapita  Wine_PerCapita
# count        122.000000      122.000000
# mean          96.598361       66.598361
# std           81.435028       88.121503
# min            1.000000        1.000000
# 25%           25.500000        5.000000
# 50%           82.500000       16.000000
# 75%          142.500000      112.750000
# max          373.000000      370.000000

# %%
df.isnull()
# Out:
#      Country  Region  Hemisphere  HappinessScore    HDI  GDP_PerCapita  \
# 0      False   False       False           False  False          False
# 1      False   False       False           False  False          False
# 2      False   False       False           False  False          False
# 3      False   False       False           False  False          False
# 4      False   False       False           False  False          False
# ..       ...     ...         ...             ...    ...            ...
# 117    False   False       False           False  False          False
# 118    False   False       False           False  False          False
# 119    False   False       False           False  False          False
# 120    False   False       False           False  False          False
# 121    False   False       False           False  False          False
#
#      Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita
# 0             False             False           False
# ...

# %% [markdown]
# HappinessScore = A metric measured in 2016 by asking the sampled people the question: "How would you rate your happiness on a scale of 0 to 10 where 10 is the happiest"
#
# HDI = Human Development Index by United Nations Development Programme

# %%
df.groupby('Hemisphere').Wine_PerCapita.mean().sort_values(ascending=False)
# Out:
# Hemisphere
# north    72.902174
# south    63.428571
# noth     10.250000
# both      9.000000
# Name: Wine_PerCapita, dtype: float64

# %%
df.loc[df['Hemisphere'] == 'noth']
# Out:
#         Country        Region Hemisphere  HappinessScore  HDI  GDP_PerCapita  \
# 46        Japan  Eastern Asia       noth           5.921  907         38.972
# 51  South Korea  Eastern Asia       noth           5.835  900         27.105
# 70        China  Eastern Asia       noth           5.245  748          8.117
# 84     Mongolia  Eastern Asia       noth           4.907  743          3.694
#
#     Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita  \
# 46              77               202              16
# 51             140                16               9
# 70              79               192               8
# 84              77               189               8
#
#     Total_alcohol_consumption_PerCapita
# 46                                  295
# 51                                  165
# 70                                  279
# 84                                  274

# %%
df.loc[df['Hemisphere'] == 'noth', ['Hemisphere']] = 'north'

# %%
df.loc[df['Hemisphere'] == 'noth']
# Out:
# Empty DataFrame
# Columns: [Country, Region, Hemisphere, HappinessScore, HDI, GDP_PerCapita, Beer_PerCapita, Spirit_PerCapita, Wine_PerCapita, Total_alcohol_consumption_PerCapita]
# Index: []

# %%
df.groupby('Hemisphere').Beer_PerCapita.mean().sort_values(ascending=False)
# Out:
# Hemisphere
# both     157.400000
# south    144.857143
# north    134.937500
# Name: Beer_PerCapita, dtype: float64

# %%
sns.boxplot(data = df,y="Beer_PerCapita",x="Hemisphere")
plt.title('Beer Consumption PerCapita in differnt Hemisphere')
plt.savefig(".Features of Species.png", dpi=1000,bbox_inches='tight') #dpi is the image size, have to save the fig before showing the plot!!
plt.show()

# %%
Total_alcohol_consumption = df["Beer_PerCapita"] + df["Spirit_PerCapita"]+ df["Wine_PerCapita"]
df["Total_alcohol_consumption_PerCapita"] = Total_alcohol_consumption
print(df)
# Out:
#          Country                           Region Hemisphere  HappinessScore  \
# 0        Denmark                   Western Europe      north           7.526
# 1    Switzerland                   Western Europe      north           7.509
# 2        Iceland                   Western Europe      north           7.501
# 3         Norway                   Western Europe      north           7.498
# 4        Finland                   Western Europe      north           7.413
# ..           ...                              ...        ...             ...
# 117     Tanzania               Sub-Saharan Africa      south           3.666
# 118      Liberia               Sub-Saharan Africa      north           3.622
# 119        Benin               Sub-Saharan Africa      north           3.484
# 120         Togo               Sub-Saharan Africa      north           3.303
# 121        Syria  Middle East and Northern Africa      north           3.069
#
# ...

# %%
df.groupby("Hemisphere").Total_alcohol_consumption_PerCapita.mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Hemisphere'>

# %%
df[["Spirit_PerCapita","Country", "Region"]].sort_values(by='Spirit_PerCapita', ascending=False )
# Out:
#      Spirit_PerCapita             Country                       Region
# 54                373             Belarus   Central and Eastern Europe
# 107               326               Haiti  Latin America and Caribbean
# 49                326  Russian Federation   Central and Eastern Europe
# 39                293            Slovakia   Central and Eastern Europe
# 31                258            Thailand            Southeastern Asia
# ..                ...                 ...                          ...
# 106                 1                Mali           Sub-Saharan Africa
# 91                  1            Cameroon           Sub-Saharan Africa
# 114                 1                Chad           Sub-Saharan Africa
# 101                 1             Senegal           Sub-Saharan Africa
# 100                 1          Rep. Congo           Sub-Saharan Africa
#
# [122 rows x 3 columns]

# %%
sns.boxplot(data = df,y="Total_alcohol_consumption_PerCapita",x="Region")
plt.title('Alcohol consumption in differnt Region')
plt.savefig(".Regionalconsumption.png", dpi=1000,bbox_inches='tight') #dpi is the image size, have to save the fig before showing the plot!!
plt.show()

# %%
df['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 28
# Central and Eastern Europe         27
# Latin America and Caribbean        23
# Western Europe                     20
# Middle East and Northern Africa    11
# Southeastern Asia                   5
# Eastern Asia                        4
# Australia and New Zealand           2
# North America                       2
# Name: Region, dtype: int64

# %%
df.groupby("Hemisphere").Total_alcohol_consumption_PerCapita.mean()
# Out:
# Hemisphere
# both     261.800000
# north    314.281250
# south    248.238095
# Name: Total_alcohol_consumption_PerCapita, dtype: float64

# %%
sns.kdeplot(data=df, x="HappinessScore", hue="Hemisphere")
# Out:
# <AxesSubplot:xlabel='HappinessScore', ylabel='Density'>

# %%
sns.distplot(df.Total_alcohol_consumption_PerCapita)
# Out:
# /Users/Anson/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total_alcohol_consumption_PerCapita', ylabel='Density'>

# %%
import statsmodels.formula.api as smf
p = sns.regplot(x = df.GDP_PerCapita, y = df.Total_alcohol_consumption_PerCapita)

# %%
 import statsmodels.formula.api as smf
p = sns.regplot(x = df.GDP_PerCapita , y = df.Spirit_PerCapita)

# %%
 import statsmodels.formula.api as smf
p = sns.regplot(x = df.GDP_PerCapita , y = df.Wine_PerCapita)

# %%
df.corr()
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>
