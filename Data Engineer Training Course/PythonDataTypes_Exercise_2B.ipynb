# %% [markdown]
# # Python Data Types & Containers Exercise 2B

# %% [markdown]
# 1. Extend a list without append.

# %%
x = [10, 20, 30]
y = [40, 50, 60]

x[:0] = y

print(x)
# Out:
# [40, 50, 60, 10, 20, 30]

# %% [markdown]
# 2. Write a program to clone or copy a list.

# %%
original_list = [1, 2, 3, 4, 5]
cloned_list = original_list[:]

print(cloned_list)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 3. Shuffle and print a specified list.

# %%
import random

my_list = [1, 2, 3, 4, 5]

random.shuffle(my_list)

print(my_list)
# Out:
# [2, 3, 5, 1, 4]

# %% [markdown]
# 4. Get the difference between the two lists.
#
# ```
# eg.
# list1 = [1, 2, 3, 4]
# list2 = [1, 2]
# difference = [3, 4]
# ```

# %%
list1 = [1, 2, 3, 4]
list2 = [1, 2]

difference = list(set(list1) - set(list2))

print(difference)
# Out:
# [3, 4]

# %% [markdown]
# 5. Append a list to the second list.

# %%
#Using the extend() method:
list1 = [1, 2, 3]
list2 = [4, 5, 6]

list1.extend(list2)

print(list1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#Using the concatenation operator (+):
list1 = [1, 2, 3]
list2 = [4, 5, 6]

list3 = list1 + list2

print(list3)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 6. Write a program to store student information in a dictionary. Accept the student’s name, age, and university name.

# %%
student = {}

name = input("Enter student's name: ")
age = input("Enter student's age: ")
university = input("Enter student's university name: ")

student['name'] = name
student['age'] = age
student['university'] = university

print("Student information:")
print("Name:", student['name'])
print("Age:", student['age'])
print("University:", student['university'])
# Out:
# Enter student's name: A
# Enter student's age: 10
# Enter student's university name: ABC
# Student information:
# Name: A
# Age: 10
# University: ABC

# %% [markdown]
# 7. Find common items from two lists.

# %%
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]

common_items = list(set(list1) & set(list2))

print(common_items)
# Out:
# [4, 5]

# %% [markdown]
# 8. Select the odd items of a list.

# %%
my_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]

odd_items = [item for item in my_list if item % 2 != 0]

print(odd_items)
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# 9. Given the string "It is a far, far better thing that I do, than I have ever done; it is a far, far better rest that I go to than I have ever known.", create a new string "thing rest" from it.

# %%
original_string = "It is a far, far better thing that I do, than I have ever done; it is a far, far better rest that I go to than I have ever known."

# Split the original string into words
words = original_string.split()

# Extract the required words "thing" and "rest"
required_words = [word for word in words if word.lower() in ['thing', 'rest']]

# Create the new string by joining the required words
new_string = ' '.join(required_words)

print(new_string)
# Out:
# thing rest

# %% [markdown]
# 10. Find the list in a list of lists whose sum of elements is the highest.
#
# ```
# eg.
# for the list [[2,3,4], [4,5,6], [10,11,12], [7,8,9]]
# the sublist [10,11,12] has the greatest sum of elements
# ```

# %%
list_of_lists = [[2, 3, 4], [4, 5, 6], [10, 11, 12], [7, 8, 9]]

max_sum = float('-inf')  # Initialize max_sum with negative infinity
max_sublist = None

for sublist in list_of_lists:
    sublist_sum = sum(sublist)
    if sublist_sum > max_sum:
        max_sum = sublist_sum
        max_sublist = sublist

print("The sublist",max_sublist,"has highest sum of elements")
# Out:
# The sublist [10, 11, 12] has highest sum of elements
