# %%
# !pip install --upgrade google-cloud-bigquery

# %%
pip install db-dtypes
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
# search for credentials in the GCP Console
# create a service account - give access to BigQuery 
# click the service account and create key - download json
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:/Users/User/Downloads/breastcancerprediction1989-36b881be8dd2.json" #Give your path here

# %%
# %reload_ext google.cloud.bigquery

# %%
# %%bigquery df
# select * from breastcancerprediction1989.breastcancerdb.breast_cancer;
# Out:
# ...
# Downloading: 100%|█████████████████████████████████████████████████████████████| 569/569 [00:01<00:00, 294.05rows/s]

# %%
df.head(15)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    8510426         B       13.540         14.36           87.46      566.3
# 1    8510653         B       13.080         15.71           85.63      520.0
# 2    8510824         B        9.504         12.44           60.34      273.9
# 3     854941         B       13.030         18.42           82.61      523.8
# 4     857156         B       13.490         22.30           86.91      561.0
# 5     857343         B       11.760         21.60           74.72      427.9
# 6     857373         B       13.640         16.34           87.21      571.8
# 7   85759902         B       11.520         18.75           73.34      409.0
# 8     858477         B        8.618         11.79           54.34      224.5
# 9     858981         B        8.598         20.98           54.66      221.8
# 10    859196         B        9.173         13.86           59.20      260.9
# ...

# %%
df
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    8510426         B       13.540         14.36           87.46      566.3
# 1    8510653         B       13.080         15.71           85.63      520.0
# 2    8510824         B        9.504         12.44           60.34      273.9
# 3     854941         B       13.030         18.42           82.61      523.8
# 4     857156         B       13.490         22.30           86.91      561.0
# ..       ...       ...          ...           ...             ...        ...
# 564   873843         B       11.410         14.92           73.53      402.0
# 565   891703         B       11.850         17.46           75.54      432.7
# 566   902975         B       12.210         14.09           78.78      462.0
# 567   862009         B       13.450         18.30           86.60      555.1
# 568   903811         B       14.060         17.18           89.75      609.1
#
# ...
