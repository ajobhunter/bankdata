# %% [markdown]
# # Danger Garden Inventory

# %% [markdown]
# You’re a data analyst in Danger Garden, help us to analyze our inventory data.

# %% [markdown]
# 1. Data for all of the locations of Danger Garden is in the file `PP-L1p-Inventory.csv`. Load the data into a DataFrame called `inventory_df`

# %%
import pandas as pd
inventory_df = pd.read_csv("https://drive.google.com/u/1/uc?id=1FclV2PgZG7gtEGYflQGl8StfgS0Wsc5S&export=download")

# Type your code below

# %% [markdown]
# 2. Inspect the first 5 rows of inventory.

# %%
# Type your code below
inventory_df.head(5)
# Out:
#         location  product_type     product_description  quantity  price
# 0         Queens         seeds                   daisy        57   6.99
# 1       Brooklyn         seeds              calla lily         0  19.99
# 2       Brooklyn  pest_control           insect killer        80  12.99
# 3  Staten Island  garden tools             wheelbarrow         0  89.99
# 4  Staten Island       planter  8 inch plastic planter        53   3.99

# %% [markdown]
# 3. A customer just emailed you asking what products are sold at your Staten Island location. Select these rows and save them to `staten_island`.

# %%
# Type your code below
staten_island = inventory_df[(inventory_df.location == "Staten Island")]
staten_island
# Out:
#          location  product_type         product_description  quantity  price  \
# 3   Staten Island  garden tools                 wheelbarrow         0  89.99
# 4   Staten Island       planter      8 inch plastic planter        53   3.99
# 8   Staten Island  pest_control                 weed killer         8  23.99
# 9   Staten Island         seeds                  calla lily        46  19.99
# 11  Staten Island  pest_control               insect killer        74  12.99
# 15  Staten Island         seeds                       daisy         4   6.99
# 17  Staten Island  garden tools                        rake         4  13.99
# 22  Staten Island  garden tools                       spade        93  19.99
# 25  Staten Island       planter  20 inch terracotta planter         0  17.99
# 27  Staten Island         seeds                      tomato        85  13.99
#
#     in_stock
# 3      False
# 4       True
# 8       True
# 9       True
# 11      True
# 15      True
# 17      True
# ...

# %% [markdown]
# 4. We don't want to share all information to the client, let's just send them `product_type` and `product_description`.

# %%
# Type your code below
staten_island[["product_type","product_description"]]
# Out:
#     product_type         product_description
# 3   garden tools                 wheelbarrow
# 4        planter      8 inch plastic planter
# 8   pest_control                 weed killer
# 9          seeds                  calla lily
# 11  pest_control               insect killer
# 15         seeds                       daisy
# 17  garden tools                        rake
# 22  garden tools                       spade
# 25       planter  20 inch terracotta planter
# 27         seeds                      tomato

# %% [markdown]
# 5. Another customer emails to ask what types of seeds are sold at the Brooklyn location. Show the related rows.

# %%
# Type your code below
inventory_df[(inventory_df.location == "Brooklyn") & (inventory_df.product_type == "seeds")]
# Out:
#     location product_type product_description  quantity  price
# 1   Brooklyn        seeds          calla lily         0  19.99
# 21  Brooklyn        seeds              tomato         0  13.99
# 26  Brooklyn        seeds               daisy        50   6.99

# %% [markdown]
# 6. Add a column to `inventory_df` called `in_stock` which is True if quantity is greater than 0 and False if quantity equals 0.

# %%
# Type your code below
inventory_df["in_stock"] = inventory_df.quantity > 0

# %%
inventory_df
# Out:
#          location  product_type         product_description  quantity  price  \
# 0          Queens         seeds                       daisy        57   6.99
# 1        Brooklyn         seeds                  calla lily         0  19.99
# 2        Brooklyn  pest_control               insect killer        80  12.99
# 3   Staten Island  garden tools                 wheelbarrow         0  89.99
# 4   Staten Island       planter      8 inch plastic planter        53   3.99
# 5        Brooklyn  pest_control                 weed killer        76  23.99
# 6          Queens  pest_control               insect killer         0  12.99
# 7        Brooklyn  garden tools                 wheelbarrow        82  89.99
# 8   Staten Island  pest_control                 weed killer         8  23.99
# 9   Staten Island         seeds                  calla lily        46  19.99
# 10       Brooklyn       planter      8 inch plastic planter        26   3.99
# ...

# %% [markdown]
# 7. Danger Garden wants to know how valuable their current inventory is.
#
# Create a column called `total_value` that is equal to price multiplied by quantity.

# %%
# Type your code below
inventory_df["total_value"] = inventory_df.price * inventory_df.quantity

# %%
inventory_df["total_value"]
# Out:
# 0      398.43
# 1        0.00
# 2     1039.20
# 3        0.00
# 4      211.47
# 5     1823.24
# 6        0.00
# 7     7379.18
# 8      191.92
# 9      919.54
# 10     103.74
# 11     961.26
# 12     293.79
# 13     519.74
# 14     383.84
# 15      27.96
# 16    8819.02
# 17      55.96
# 18     209.85
# 19      89.95
# 20     719.64
# 21       0.00
# 22    1859.07
# 23    1565.13
# 24    1899.05
# 25       0.00
# 26     349.50
# 27    1189.15
# 28     629.55
# Name: total_value, dtype: float64

# %%
inventory_df
# Out:
#          location  product_type         product_description  quantity  price  \
# 0          Queens         seeds                       daisy        57   6.99
# 1        Brooklyn         seeds                  calla lily         0  19.99
# 2        Brooklyn  pest_control               insect killer        80  12.99
# 3   Staten Island  garden tools                 wheelbarrow         0  89.99
# 4   Staten Island       planter      8 inch plastic planter        53   3.99
# 5        Brooklyn  pest_control                 weed killer        76  23.99
# 6          Queens  pest_control               insect killer         0  12.99
# 7        Brooklyn  garden tools                 wheelbarrow        82  89.99
# 8   Staten Island  pest_control                 weed killer         8  23.99
# 9   Staten Island         seeds                  calla lily        46  19.99
# 10       Brooklyn       planter      8 inch plastic planter        26   3.99
# ...

# %%
inventory_df.sum()
# Out:
# location               QueensBrooklynBrooklynStaten IslandStaten Isla...
# product_type           seedsseedspest_controlgarden toolsplanterpest_...
# product_description    daisycalla lilyinsect killerwheelbarrow8 inch ...
# quantity                                                            1182
# price                                                             667.71
# in_stock                                                              24
# total_value                                                     31639.18
# dtype: object

# %%
sum(inventory_df["total_value"])
# Out:
# 31639.179999999997

# %%
import pandas as pd
# Let's revisit our clinic data

df = pd.DataFrame([
        ['January', 100, 100, 23, 100],
        ['February', 51, 45, 145, 45],
        ['March', 81, 96, 65, 96],
        ['April', 80, 80, 54, 180],
        ['May', 51, 54, 54, 154],
        ['June', 112, 109, 79, 129]
    ],
    columns=[
        'month', 'clinic_east',
        'clinic_north', 'clinic_south',
        'clinic_west'
    ]
)

# %%
df
# Out:
#       month  clinic_east  clinic_north  clinic_south  clinic_west
# 0   January          100           100            23          100
# 1  February           51            45           145           45
# 2     March           81            96            65           96
# 3     April           80            80            54          180
# 4       May           51            54            54          154
# 5      June          112           109            79          129
